# %%
from astropy.io import fits
import pandas as pd
import numpy as np

# %%
# fits_image_filename = 'C:/Users/madin/Downloads/rcsed_v2_clean.fits'

# %%
fits_image_filename = 'C:/Users/madin/Downloads/wget-1.20.3-win64/rcsed_v2_clean.fits'

# %%
with fits.open(fits_image_filename, memmap=False) as hdul:
    hdul.info()
#     print(hdul[1].header[1])
#     print(data)
    z= hdul[1].data
    print(z)
# Out:
# Filename: C:/Users/madin/Downloads/wget-1.20.3-win64/rcsed_v2_clean.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      16   (73531,)   uint8
# ...

# %%
print(z.shape)
# Out:
# (4105516,)

# %%
data=z

# %%
print(len(z))
# Out:
# 4105516

# %%
print(len(data[0]))
print(type(data[0]))
print(data[0])
print(data[0]['ra'])
# Out:
# 559
# <class 'astropy.io.fits.fitsrec.FITS_record'>
# ...

# %%
print(len(data.columns))
print(data.columns)
# Out:
# 559
# ColDefs(
#     name = 'ind'; format = 'J'; null = -2147483648
#     name = 'ra'; format = 'D'
#     name = 'dec'; format = 'D'
#     name = 'z_sdss'; format = 'D'
#     name = 'zerr_sdss'; format = 'D'
#     name = 'specObjID_sdss'; format = 'D'
#     name = 'bestObjID_sdss'; format = 'K'; null = -9223372036854775808
#     name = 'plate_sdss'; format = 'I'; null = -32768
#     name = 'mjd_sdss'; format = 'J'; null = -2147483648
#     name = 'fiberID_sdss'; format = 'I'; null = -32768
#     name = 'z_2df'; format = 'E'
#     name = 'q_z_2df'; format = 'J'; null = -2147483648
#     name = 'SeqNum_2df'; format = '6A'
#     name = 'z_6df'; format = 'D'
#     name = 'quality_6df'; format = 'I'; null = -32768
#     name = 'targetname_6df'; format = '15A'
#     name = 'specid_6df'; format = 'J'; null = -2147483648
#     name = 'recno_uzc'; format = 'J'; null = -2147483648
#     name = 'z_uzc'; format = 'D'
#     name = 'z_err_uzc'; format = 'D'
#     name = 'z_cfa'; format = 'D'
# ...

# %%
print(type(data))
# Out:
# <class 'astropy.io.fits.fitsrec.FITS_rec'>

# %%
print(type(data.field(0)))
# Out:
# <class 'numpy.ndarray'>

# %%
d={}
for col in data.columns.names:
    d.update({col:data.field(col)})
df = pd.DataFrame(data=d)

print(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b7bcafd8217d> in <module>
#       4 df = pd.DataFrame(data=d)
#       5
# ----> 6 print(df.head(10))
#       7
#       8
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __repr__(self)
#     653             max_cols=max_cols,
#     654             line_width=width,
# --> 655             show_dimensions=show_dimensions,
#     656         )
#     657
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width)
#     757             show_dimensions=show_dimensions,
#     758             decimal=decimal,
# --> 759             line_width=line_width,
#     760         )
#     761         formatter.to_string()
#
# ...

# %%
for col in data.columns.names:
    df[col]=pd.DataFrame(np.array(df[col]).byteswap().newbyteorder())

# %%
print(df.head(10))
# Out:
#    ind        ra        dec    z_sdss  zerr_sdss  specObjID_sdss  \
# 0    1  0.000019  -4.760800  2.467120   0.002194    7.919679e+18
# 1    2  0.000091  24.902252  0.555936   0.000245    7.333218e+18
# 2    3  0.000346  -6.491940  0.514177   0.000130    8.047035e+18
# 3    4  0.000463  10.241074  0.654380   0.000170    6.960408e+18
# 4    5  0.000559  34.985602  0.146326   0.000021    8.044630e+18
# 5    6  0.000629  35.517842       NaN        NaN             NaN
# 6    7  0.000646 -32.597691       NaN        NaN             NaN
# 7    8  0.000686  -0.185726  0.195055   0.000009    1.228390e+18
# 8    9  0.000721  11.343976  0.442758   0.000118    6.960496e+18
# 9   10  0.000724   1.046322  0.003555   0.000021    4.358475e+17
#
#         bestObjID_sdss  plate_sdss    mjd_sdss  fiberID_sdss  ...  \
# 0                    0        7034       56564           360  ...
# 1  1237666309095751941        6513       56543           843  ...
# ...

# %%
print(len(df.keys()))
# Out:
# 559

# %%
df.to_csv(r'C:/Users/madin/OneDrive/Документы/COURSE_PROJECT_galaxies/new_data.csv')

# %%
full_df=df

# %%
data_df=pd.read_csv('C:/Users/madin/OneDrive/Документы/COURSE_PROJECT_galaxies/new_data.csv')

# %%
df.dropna(axis='columns')
